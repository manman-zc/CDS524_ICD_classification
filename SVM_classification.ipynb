# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
data_path = "/content/drive/MyDrive/Colab Notebooks/DL/"  # this is your drive
# Out:
# Mounted at /content/drive/

# %%
import json
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer

# 1. 读取数据，处理label2的格式
def load_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    texts1 = [item['text1'] for item in data]
    labels1 = [item['label1'] for item in data]
    texts2 = [item['text2'] for item in data]
    labels2 = [item['label2'].split(';') if item['label2'] else [] for item in data]
    return texts1, labels1, texts2, labels2

# 文件路径
train_file = data_path + 'train_data/train_data.json'
val_file = data_path + 'train_data/val_data.json'
test_file = data_path + 'test_data/test_data.json'  # 测试集文件

# 加载训练集、验证集和测试集
train_texts1, train_labels1, train_texts2, train_labels2 = load_data(train_file)
val_texts1, val_labels1, val_texts2, val_labels2 = load_data(val_file)
test_texts1, test_labels1, test_texts2, test_labels2 = load_data(test_file)

# 2. 特征提取并拼接
tfidf1 = TfidfVectorizer(max_features=5000)
tfidf2 = TfidfVectorizer(max_features=5000)

# %%
# 训练集特征
X_train1 = tfidf1.fit_transform(train_texts1)
X_train2 = tfidf2.fit_transform(train_texts2)
X_train_combined = np.hstack((X_train1.toarray(), X_train2.toarray()))

# 验证集特征
X_val1 = tfidf1.transform(val_texts1)
X_val2 = tfidf2.transform(val_texts2)
X_val_combined = np.hstack((X_val1.toarray(), X_val2.toarray()))

# 测试集特征
X_test1 = tfidf1.transform(test_texts1)
X_test2 = tfidf2.transform(test_texts2)
X_test_combined = np.hstack((X_test1.toarray(), X_test2.toarray()))

# 3. 处理标签
mlb = MultiLabelBinarizer()
y_train2 = mlb.fit_transform(train_labels2)
y_val2 = mlb.transform(val_labels2)
y_test2 = mlb.transform(test_labels2)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['I31.800x004', 'Z98.800x612'] will be ignored
#   warnings.warn(

# %%
# 4. 训练模型
# 任务1：单标签分类
svm1 = LinearSVC(max_iter=1000)
svm1.fit(X_train_combined, train_labels1)

# 任务2：多标签分类
svm2 = OneVsRestClassifier(LinearSVC(max_iter=1000))
svm2.fit(X_train_combined, y_train2)

# 5. 在测试集上预测
y_pred1_test = svm1.predict(X_test_combined)
y_pred2_test = svm2.predict(X_test_combined)

# 6. 自定义评价指标
def custom_acc(y_true_main, y_pred_main, y_true_other, y_pred_other, mlb):
    N = len(y_true_main)
    total_score = 0.0

    for i in range(N):
        # 单标签任务：主诊断是否正确
        main_correct = 1 if y_pred_main[i] == y_true_main[i] else 0

        # 多标签任务：计算交集和真实标签数量
        true_labels = set(y_true_other[i])  # 真实标签（列表）
        pred_labels = set(mlb.classes_[np.where(y_pred_other[i] == 1)[0]])  # 预测标签
        intersection = len(true_labels & pred_labels)
        num_true_other = len(true_labels)

        # 计算多标签部分的得分
        if num_true_other > 0:
            other_score = intersection / num_true_other
        else:
            other_score = 0.0  # 避免除以0

        # 总得分：0.5 * 单标签得分 + 0.5 * 多标签得分
        score = 0.5 * main_correct + 0.5 * other_score
        total_score += score

    # 平均得分
    acc = total_score / N
    return acc

# 7. 在测试集上评估
test_acc = custom_acc(test_labels1, y_pred1_test, test_labels2, y_pred2_test, mlb)
print(f"Test Set Custom Accuracy (Acc): {test_acc:.4f}")

# 8. 输出测试集前5个样本的预测结果
print("\nTest Set Sample Predictions:")
for i in range(min(5, len(test_texts1))):
    print(f"Sample {i+1}:")
    print(f"Text1: {test_texts1[i]}")
    print(f"Predicted Label1: {y_pred1_test[i]}, True Label1: {test_labels1[i]}")
    print(f"Text2: {test_texts2[i]}")
    pred_labels2 = mlb.classes_[np.where(y_pred2_test[i] == 1)[0]].tolist()
    print(f"Predicted Label2: {pred_labels2}")
    print(f"True Label2: {test_labels2[i]}")
    print("-" * 50)
# Out:
# Test Set Custom Accuracy (Acc): 0.5900
#
# Test Set Sample Predictions:
# Sample 1:
# Text1: 疾病：冠状动脉粥样硬化性心脏病，糖尿病，冠心病不稳定型心绞痛，肝炎，高血压，结核，心绞痛，冠状动脉支架，胆囊息肉，囊肿，双肺细支气管炎，脂肪肝；症状：畸形，隆起，咳痰，咳嗽，大汗，对称，胸痛，喘，头痛，凹陷，胸闷，黑朦，憨喘，疼痛，头晕，放射痛，心绞痛，水肿，囊肿，结节，狭窄；检查项目：呼吸音，P，体重，湿性啰音，BP，心率，R1，T3，查体，载脂蛋白E，血细胞分析，血脂，血小板体积，肌钙蛋白I，酶法，化验，脂蛋白，小密低密度脂蛋白，大血小板比率，血清肌钙蛋白I，色谱法，甘油三酯，电解质葡萄糖测定，血小板压积，糖化血红蛋白测定，单核细胞计数，肝功，同型半胱氨酸，病理性杂音，血小板分布宽度，甲功五项，超声检查。于2024-11-11在介入诊疗中心行冠状动脉造影术。常规消毒，铺洞巾，局部麻醉，右侧动脉穿刺，行左右冠状动脉造影，感染标志物系列，动静脉超声，尿常规，颈动脉超声，CRP，L↑，补体C1q，BNP，动脉造影，血沉，糖化血红蛋白，胸部CT，降钙素原，大便分析，HBsAb，沉渣，心脏彩超，尿肾功，凝血常规，HCV-Ab，CMIA，心律，反跳痛，压痛；治疗方法：阿司匹林，血脂康；身体部位：双肺，心前区，各瓣膜听诊区，背部，痰，大小便，肩背部，胸廓，腹部，双下肢，血小板，脂肪肝，室间隔基底段，大便，脾，左前降支，双下肢动脉内中膜，室壁，胆，左冠，左主干，肝，胰，主动脉瓣，双侧颈动脉内中膜，右冠状动脉，腹，双下肢足背动脉，右冠；药物：血脂康，麝香保心丸，阿司匹林，硝酸甘油，他汀；手术：冠状动脉支架植入，冠状动脉造影术，球囊扩张术
# Predicted Label1: I20.000, True Label1: I21.401
# Text2: 疾病：肝炎，高血压，糖尿病，传染病，结核，胆囊息肉，囊肿，脂肪肝，双肺细支气管炎；症状：囊肿，结节，节段性室壁运动异常；室间隔基底段增厚，狭窄，感染，闭塞，出血，发黑；检查项目：大血小板比率，肌钙蛋白I，肝功，电解质葡萄糖测定，色谱法，血小板分布宽度，血小板压积，血清肌钙蛋白I测定，血脂肾功，酶法，血小板体积，血细胞分析，糖化血红蛋白测定，化验，单核细胞计数，糖化血红蛋白，CMIA，脂蛋白，颈动脉超声，a，HBsAb，尿常规，载脂蛋白E，凝血常规，胸部CT，补体C1q，BNP，大便分析，心脏彩超，肝胆胰脾肾超声，血沉，甘油三酯，同型半胱氨酸，HCV-Ab，沉渣，甲功五项，CRP，尿肾功，降钙素原，血糖，血压，动脉造影，心率；治疗方法：瑞舒伐他汀钙片，通心络胶囊，雷贝拉唑钠肠溶片，阿司匹林肠溶片，硫酸氢氯吡格雷片，尼可地尔片，氯吡格雷抗栓药物，阿司匹林；身体部位：双侧颈动脉内中膜，双下肢动脉内中膜，主动脉瓣，双肺纤维灶双肺上叶局限性肺气肿脂肪肝，室间隔基底段，肝，左冠，左前降支，左主干，右冠，钝缘支，右冠状动脉，对角支，牙龈，皮肤黏膜，大便；药物：阿司匹林，汉丰，尼可地尔片，雷贝拉唑钠肠溶片，瑞舒伐他汀钙片，依折麦布片，硫酸氢氯吡格雷片，通心络胶囊，氯吡格雷抗栓药物；手术：球囊扩张术，冠状动脉造影术
# Predicted Label2: ['E78.500', 'I25.103', 'I70.203', 'K76.000', 'R91.x00x003']
# True Label2: ['I70.203']
# --------------------------------------------------
# Sample 2:
# Text1: 疾病：结核，冠心病，糖尿病，慢性支气管炎，肝炎，高血压，不稳定型心绞痛，冠状动脉粥样硬化性心脏病，室上性早搏，室性早搏；症状：恶心，胸闷，感喘，胸痛，头痛，对称，畸形，腹泻，腹胀，头晕，隆起，黑朦，腹痛，放射痛，疼痛，出汗，室性早搏，水肿，结石，囊肿，斑块，心绞痛，结节，室上性早搏；检查项目：心率，体重，湿性啰音，呼吸音，心电图，查体，心脏超声，T36CP，尿常规，碳酸氢根，子宫声像图，氧分压，肾输尿管膀胱超声，B型钠尿肽，促甲状腺激素，血管超声，浅静脉声像图，电解质氯，干化学法，颈动脉超声，凝血常规，ECLIA，冠状动脉CTA，子宫附件超声，血气全项，甲功五项，凝血酶原，病理性杂音，二氧化碳总含量，胸部CT，膀胱声像图，粒细胞，湿啰音，反跳痛，压痛；治疗方法：波立维，瑞舒伐他汀；身体部位：心前区，后背，三尖瓣，大小便，双肺，主动脉瓣，胸廓，冠状动脉，双肾，各瓣膜听诊区，腹部，双下肢动脉，深静脉，胆囊，肝，双下肢，左前降支，支中段心肌桥，腹；药物：瑞舒伐他汀，波立维；手术：胃息肉切除
# Predicted Label1: I20.800x007, True Label1: I20.800x007
# Text2: 疾病：高血压，胃息肉，房性早搏，室性早搏，传染病，结核，糖尿病，肝炎，慢性支气管炎，室上性早搏；症状：房性早搏，心律失常，室性早搏，心动过缓，多发结石，室上性早搏，感染，窦性心律；检查项目：凝血常规，血管超声，干化学法，甲功五项，颈动脉超声，尿常规，浅静脉声像图，凝血酶原，B型钠尿肽，电解质氯，ECLIA，子宫附件超声，胸部CT，超声，粒细胞，子宫声像，促甲状腺激素，血脂，血气全项，二氧化碳总含量，BNP，心率，血常规，心电图，血压，碳酸氢根，肾输尿管膀胱超声，冠状动脉CTA，肝功，氧分压，电解质，膀胱声像图，肾功，血糖；治疗方法：通心络胶囊，瑞舒伐他汀钙片，尼可地尔片；身体部位：肝，深静脉，胆囊，双下肢动脉，心肌桥，双侧输尿管，双肾，左前降支；药物：通心络胶囊，尼可地尔片，瑞舒伐他汀钙片；手术：胃息肉切除术，胃息肉切除
# Predicted Label2: []
# True Label2: ['I49.100x001']
# --------------------------------------------------
# Sample 3:
# Text1: 疾病：脑梗死，高血压，肝炎，糖尿病，心绞痛，结核，冠状动脉粥样硬化性心脏病，冠状动脉搭桥，不稳定型心绞痛，冠状动脉粥样硬化，慢性支气管炎，肺气肿；症状：怒张，畸形，粘痰，头痛，胸闷，呕吐，咳嗽，肿大，胸痛，隆起，凹陷，恶心，对称，头晕，肺大疱，钙化灶，气肿，结节，心绞痛，结石，渗血，渗液，心悸，狭窄，出血，水肿；检查项目：血压，干、湿性啰音，收缩压，体重，杂音，呼吸音，体格检查，心率，移动性浊音，半胱氨酸，ApoB，尿微量白蛋白，散射比浊法，尿β2微球蛋I，a1微球蛋白，肌钙蛋白，心电图，病理性杂音，H白，胸部X线，比浊法，冠状动脉CTA，叩痛，胸部CT，尿免疫球蛋白G，肠鸣音，尿转铁蛋白，单核细胞计数，红细胞压积，压痛，心脏超声，心脏彩超，尿糖，尿肌酐，反跳痛，甲功三项，葡萄糖测定，大便分析，凝血功能，肝素，糖化血红蛋白测定，湿性啰音，冠脉造影，C一反应蛋白测定，血小板功能动态监测，色谱法，查体，感染标志物系列，末梢血，凝血常规，CRP，电解质，酶法，心律；治疗方法：硝酸甘油，冠脉搭桥术；身体部位：胸廓，大小便，甲状腺，心前区，双肺，颈静脉，气管，双侧颈动脉，腹部，腹，肝，左房，主动脉瓣，脾，左室壁，室间隔，左肺上叶，左室，胆囊，各瓣膜听诊区，肾区，二、三尖瓣，右冠，后降支，冠脉，对角支，回旋支中段，管腔，股动脉，前降支中段，双侧肾上腺，左主干末端，左室后支，双下肢；药物：硝酸甘油，肝素；手术：冠脉搭桥术，冠状动脉搭桥
# Predicted Label1: I21.401, True Label1: I21.401
# Text2: 疾病：肝炎，高血压病，结核，脑梗死，肺大疱，阵发性心房颤动，糖尿病，胆囊结石，肺气肿，慢性支气管炎，冠状动脉粥样硬化；症状：阵发性心房颤动，心房颤动，狭窄，出血，返流，肺气肿，纤维灶双侧肾上腺显粗，增生可能冠状动脉搭桥术后CTA所见符合冠状动脉粥样硬化伴管腔不同程度狭窄，结节，胸闷，胸痛；检查项目：尿糖，收缩压，单核细胞计数，红细胞压积，肌钙蛋白，尿β2微球蛋I，H白，半胱氨酸，血压，尿免疫球蛋白G，葡萄糖测定，血小板功能动态监测，凝血常规，C一反应蛋白测定，甲功三项，糖化血红蛋白测定，尿肌酐，感染标志物，尿转铁蛋白，尿微量白蛋白，散射比浊法，比浊法，电解质，胸部CT，酶法，凝血功能，心脏彩超，a1微球蛋白，冠状动脉CTA，CRP，色谱法，肝素，肌酸激酶，血常规，血糖，肌钙蛋白I，末梢血，BNP，大便分析，心脏超声，肝肾功，血脂；治疗方法：冠脉搭桥术；身体部位：冠脉，左室后支，尿液，主动脉瓣，左主干末端，室间隔，室壁，左室，前降支中段，双肺，管腔，右冠，左室壁，双侧肾上腺，左房，二、三尖瓣；药物：青霉素，雷贝拉唑钠肠溶片，盐酸曲美他嗪片，速效救心丸，单硝酸异山梨酯缓释片，利伐沙班片，普罗布考片，琥珀酸美托洛尔缓释片，阿托伐他汀钙片，沙库巴曲沙坦钠片；手术：冠脉搭桥术，冠状动脉搭桥术
# Predicted Label2: ['I25.103']
# True Label2: ['I10.x00x032']
# --------------------------------------------------
# Sample 4:
# Text1: 疾病：冠心病不稳定型心绞痛，高血压，肺结节，冠状动脉粥样硬化性心脏病，不稳定型心绞痛，椎体终板炎，筋膜炎；症状：头晕，水肿，胸痛，咳嗽，头痛，心悸，咯血，腹痛，凹陷，出汗，胸闷，咳痰，发热，恶心，呕吐，喘，隐痛，隆起，腹泻，增厚，室上性早搏，狭窄，膨出，斑块形成（右侧多发）。双下肢动脉+双下肢深静脉+双下肢浅静脉超声：左侧小腿肌间静脉扩张，扩大，心律齐；检查项目：呼吸音，查体，Murphys征，干、湿性啰音，血压，R1，病理性杂音，反跳痛，肠鸣音，压痛，叩痛，心率，移动性浊音，胸部CT，BP，P，T3，丙氨酸转氨酶，天门冬氨酸转氨酶，心脏彩超，白蛋白，MR，潜血，ST-T，血，浅静脉超声，糖化血红蛋白，血检，前白蛋白，血沉，湿性啰音；治疗方法：硝苯地平缓释片；身体部位：肢体，肝，脾，双肺，肾区，左肺，心前区，腹，各瓣膜听诊区，双下肢，二便，右肺下叶，对角支，双下肢深静脉，左回旋支，左侧小腿肌间静脉，双侧颈动脉内中膜，腰5/1椎间盘，左主干，右冠状动脉，左前降支中段肌桥，腰椎，室间隔基底段，双下肢动脉；药物：硝苯地平缓释片；手术：冠脉造影术
# Predicted Label1: I20.800x007, True Label1: I20.000
# Text2: 疾病：高血压，结核，肝炎，高脂血症，肺结节，高血压病，慢阻肺，糖尿病，室上性早搏，椎体终板炎，筋膜炎；症状：痛经，狭窄，膨出，室上性早搏，扩张，出血，淤血，血尿，黑便，血便，瘀斑；检查项目：糖化血红蛋白，血沉，潜血，前白蛋白，血压，天门冬氨酸转氨酶，双侧颈动脉超声，血检，白蛋白，丙氨酸转氨酶，心脏彩超，ST-T，浅静脉超声，腰椎MR，肝功，肾功，电解质，血脂，血常规，血糖，心率，心电图，肌酸激酶；治疗方法：硝苯地平缓释片，阿利沙坦酯片，雷贝拉唑钠肠溶片，阿司匹林肠溶片，瑞舒伐他汀钙片；身体部位：左侧小腿肌间静脉，左回旋支，右冠状动脉，腰椎，左前降支中段肌桥，双下肢动脉，腰5/1椎间盘，左主干，胃部，双下肢深静脉，室间隔基底段，钝缘支，对角支，黏膜，皮肤；药物：硝苯地平缓释片，单硝酸异山梨酯缓释片，阿司匹林肠溶片，雷贝拉唑钠肠溶片，阿利沙坦酯片，瑞舒伐他汀钙片，阿司匹林，硝苯地平控释片，参松养心胶囊；手术：冠脉造影术
# Predicted Label2: ['I25.103', 'I70.806', 'R91.x00x003']
# True Label2: ['I70.806']
# --------------------------------------------------
# Sample 5:
# Text1: 疾病：结核，高血压病，冠心病，慢性支气管炎，肝炎，糖尿病；症状：腹泻，头晕，腹痛，咳痰，畸形，耳鸣，气，对称，头痛，水肿，隆起，咳嗽，恶心，呕吐，胸闷，凹陷；检查项目：体重，LVEF，肾动脉B超，查体，血压，病理性杂音，化验，BP，呼吸音，湿性啰音，钾，心脏彩超，心率，电解质，颈动脉B超，肾上腺CT，降压，反跳痛，压痛，血流声像图；治疗方法：降压药物；身体部位：左侧肾上腺，各瓣膜听诊区，胸廓，腹部，大小便，心前区，右侧颈动脉内中膜，双下肢，室间隔基底段，双肺，腹，双下肢足背动脉，双侧肾动脉；药物：降压药物；手术：
# Predicted Label1: I10.x00x032, True Label1: I10.x00x032
# Text2: 疾病：糖尿病，结核，高血压病，传染病，肝炎，慢性支气管炎，冠心病，脂肪肝；症状：脂肪肝；检查项目：血流声像图，肾上腺CT，颈动脉B超，化验，钾，LVEF，血糖，电解质，血压，心脏彩超，降压，肾动脉B超，心率；治疗方法：卡维地洛片，沙库巴曲沙坦钠片；身体部位：节段性室壁，双侧肾动脉，双肺，腹部，室间隔基底段，左侧肾上腺，胸部，右侧颈动脉内中膜；药物：沙库巴曲沙坦钠片，卡维地洛片；手术：
# Predicted Label2: ['K76.000']
# True Label2: ['E87.600']
# --------------------------------------------------

# %% [markdown]
# ### 使用交叉验证做调参

# %%
import json
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import GridSearchCV

# 1. 读取数据，处理label2的格式
def load_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    texts1 = [item['text1'] for item in data]
    labels1 = [item['label1'] for item in data]
    texts2 = [item['text2'] for item in data]
    labels2 = [item['label2'].split(';') if item['label2'] else [] for item in data]
    return texts1, labels1, texts2, labels2

# 文件路径
train_file = data_path + 'train_data/train_data.json'
val_file = data_path + 'train_data/val_data.json'
test_file = data_path + 'test_data/test_data.json'  # 测试集文件

# 加载训练集、验证集和测试集
train_texts1, train_labels1, train_texts2, train_labels2 = load_data(train_file)
val_texts1, val_labels1, val_texts2, val_labels2 = load_data(val_file)
test_texts1, test_labels1, test_texts2, test_labels2 = load_data(test_file)

# 合并训练集和验证集，用于交叉验证
combined_texts1 = train_texts1 + val_texts1
combined_labels1 = train_labels1 + val_labels1
combined_texts2 = train_texts2 + val_texts2
combined_labels2 = train_labels2 + val_labels2

# 2. 特征提取
tfidf1 = TfidfVectorizer(max_features=5000)
tfidf2 = TfidfVectorizer(max_features=5000)

# 合并数据特征（用于交叉验证）
X_combined1 = tfidf1.fit_transform(combined_texts1)
X_combined2 = tfidf2.fit_transform(combined_texts2)
X_combined = np.hstack((X_combined1.toarray(), X_combined2.toarray()))

# 训练集特征（用于最终训练）
X_train1 = tfidf1.transform(train_texts1)
X_train2 = tfidf2.transform(train_texts2)
X_train_combined = np.hstack((X_train1.toarray(), X_train2.toarray()))

# 测试集特征
X_test1 = tfidf1.transform(test_texts1)
X_test2 = tfidf2.transform(test_texts2)
X_test_combined = np.hstack((X_test1.toarray(), X_test2.toarray()))

# 3. 处理标签
mlb = MultiLabelBinarizer()
y_combined2 = mlb.fit_transform(combined_labels2)
y_train2 = mlb.transform(train_labels2)
y_test2 = mlb.transform(test_labels2)

# 4. 交叉验证调参
# 任务1：单标签分类
param_grid = {'C': [0.1, 1, 10, 100]}  # 调参范围
svm1 = LinearSVC(max_iter=1000)
grid_search1 = GridSearchCV(svm1, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search1.fit(X_combined, combined_labels1)
print(f"Best parameters for Task 1 (Single-label): {grid_search1.best_params_}")

# 任务2：多标签分类（用OneVsRestClassifier）
svm2_base = LinearSVC(max_iter=1000)
svm2 = OneVsRestClassifier(svm2_base)
param_grid_multi = {'estimator__C': [0.1, 1, 10, 100]}
grid_search2 = GridSearchCV(svm2, param_grid_multi, cv=5, scoring='f1_micro', n_jobs=-1)
grid_search2.fit(X_combined, y_combined2)
print(f"Best parameters for Task 2 (Multi-label): {grid_search2.best_params_}")

# 5. 用最优参数在训练集上重新训练
# 任务1
svm1_final = LinearSVC(C=grid_search1.best_params_['C'], max_iter=1000)
svm1_final.fit(X_train_combined, train_labels1)

# 任务2
svm2_final = OneVsRestClassifier(LinearSVC(C=grid_search2.best_params_['estimator__C'], max_iter=1000))
svm2_final.fit(X_train_combined, y_train2)

# 6. 在测试集上预测
y_pred1_test = svm1_final.predict(X_test_combined)
y_pred2_test = svm2_final.predict(X_test_combined)

# 7. 自定义评价指标
def custom_acc(y_true_main, y_pred_main, y_true_other, y_pred_other, mlb):
    N = len(y_true_main)
    total_score = 0.0
    for i in range(N):
        main_correct = 1 if y_pred_main[i] == y_true_main[i] else 0
        true_labels = set(y_true_other[i])
        pred_labels = set(mlb.classes_[np.where(y_pred_other[i] == 1)[0]])
        intersection = len(true_labels & pred_labels)
        num_true_other = len(true_labels)
        other_score = intersection / num_true_other if num_true_other > 0 else 0.0
        score = 0.5 * main_correct + 0.5 * other_score
        total_score += score
    acc = total_score / N
    return acc

# 8. 在测试集上评估
test_acc = custom_acc(test_labels1, y_pred1_test, test_labels2, y_pred2_test, mlb)
print(f"Test Set Custom Accuracy (Acc): {test_acc:.4f}")

# 9. 输出测试集前5个样本的预测结果
print("\nTest Set Sample Predictions:")
for i in range(min(5, len(test_texts1))):
    print(f"Sample {i+1}:")
    print(f"Text1: {test_texts1[i]}")
    print(f"Predicted Label1: {y_pred1_test[i]}, True Label1: {test_labels1[i]}")
    print(f"Text2: {test_texts2[i]}")
    pred_labels2 = mlb.classes_[np.where(y_pred2_test[i] == 1)[0]].tolist()
    print(f"Predicted Label2: {pred_labels2}")
    print(f"True Label2: {test_labels2[i]}")
    print("-" * 50)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['I31.800x004', 'Z98.800x612'] will be ignored
#   warnings.warn(
# Best parameters for Task 1 (Single-label): {'C': 0.1}
# Best parameters for Task 2 (Multi-label): {'estimator__C': 10}
# Test Set Custom Accuracy (Acc): 0.6025
#
# Test Set Sample Predictions:
# Sample 1:
# Text1: 疾病：冠状动脉粥样硬化性心脏病，糖尿病，冠心病不稳定型心绞痛，肝炎，高血压，结核，心绞痛，冠状动脉支架，胆囊息肉，囊肿，双肺细支气管炎，脂肪肝；症状：畸形，隆起，咳痰，咳嗽，大汗，对称，胸痛，喘，头痛，凹陷，胸闷，黑朦，憨喘，疼痛，头晕，放射痛，心绞痛，水肿，囊肿，结节，狭窄；检查项目：呼吸音，P，体重，湿性啰音，BP，心率，R1，T3，查体，载脂蛋白E，血细胞分析，血脂，血小板体积，肌钙蛋白I，酶法，化验，脂蛋白，小密低密度脂蛋白，大血小板比率，血清肌钙蛋白I，色谱法，甘油三酯，电解质葡萄糖测定，血小板压积，糖化血红蛋白测定，单核细胞计数，肝功，同型半胱氨酸，病理性杂音，血小板分布宽度，甲功五项，超声检查。于2024-11-11在介入诊疗中心行冠状动脉造影术。常规消毒，铺洞巾，局部麻醉，右侧动脉穿刺，行左右冠状动脉造影，感染标志物系列，动静脉超声，尿常规，颈动脉超声，CRP，L↑，补体C1q，BNP，动脉造影，血沉，糖化血红蛋白，胸部CT，降钙素原，大便分析，HBsAb，沉渣，心脏彩超，尿肾功，凝血常规，HCV-Ab，CMIA，心律，反跳痛，压痛；治疗方法：阿司匹林，血脂康；身体部位：双肺，心前区，各瓣膜听诊区，背部，痰，大小便，肩背部，胸廓，腹部，双下肢，血小板，脂肪肝，室间隔基底段，大便，脾，左前降支，双下肢动脉内中膜，室壁，胆，左冠，左主干，肝，胰，主动脉瓣，双侧颈动脉内中膜，右冠状动脉，腹，双下肢足背动脉，右冠；药物：血脂康，麝香保心丸，阿司匹林，硝酸甘油，他汀；手术：冠状动脉支架植入，冠状动脉造影术，球囊扩张术
# Predicted Label1: I20.000, True Label1: I21.401
# Text2: 疾病：肝炎，高血压，糖尿病，传染病，结核，胆囊息肉，囊肿，脂肪肝，双肺细支气管炎；症状：囊肿，结节，节段性室壁运动异常；室间隔基底段增厚，狭窄，感染，闭塞，出血，发黑；检查项目：大血小板比率，肌钙蛋白I，肝功，电解质葡萄糖测定，色谱法，血小板分布宽度，血小板压积，血清肌钙蛋白I测定，血脂肾功，酶法，血小板体积，血细胞分析，糖化血红蛋白测定，化验，单核细胞计数，糖化血红蛋白，CMIA，脂蛋白，颈动脉超声，a，HBsAb，尿常规，载脂蛋白E，凝血常规，胸部CT，补体C1q，BNP，大便分析，心脏彩超，肝胆胰脾肾超声，血沉，甘油三酯，同型半胱氨酸，HCV-Ab，沉渣，甲功五项，CRP，尿肾功，降钙素原，血糖，血压，动脉造影，心率；治疗方法：瑞舒伐他汀钙片，通心络胶囊，雷贝拉唑钠肠溶片，阿司匹林肠溶片，硫酸氢氯吡格雷片，尼可地尔片，氯吡格雷抗栓药物，阿司匹林；身体部位：双侧颈动脉内中膜，双下肢动脉内中膜，主动脉瓣，双肺纤维灶双肺上叶局限性肺气肿脂肪肝，室间隔基底段，肝，左冠，左前降支，左主干，右冠，钝缘支，右冠状动脉，对角支，牙龈，皮肤黏膜，大便；药物：阿司匹林，汉丰，尼可地尔片，雷贝拉唑钠肠溶片，瑞舒伐他汀钙片，依折麦布片，硫酸氢氯吡格雷片，通心络胶囊，氯吡格雷抗栓药物；手术：球囊扩张术，冠状动脉造影术
# Predicted Label2: ['E78.500', 'I25.103', 'I70.203', 'K76.000', 'R91.x00x003']
# True Label2: ['I70.203']
# --------------------------------------------------
# Sample 2:
# Text1: 疾病：结核，冠心病，糖尿病，慢性支气管炎，肝炎，高血压，不稳定型心绞痛，冠状动脉粥样硬化性心脏病，室上性早搏，室性早搏；症状：恶心，胸闷，感喘，胸痛，头痛，对称，畸形，腹泻，腹胀，头晕，隆起，黑朦，腹痛，放射痛，疼痛，出汗，室性早搏，水肿，结石，囊肿，斑块，心绞痛，结节，室上性早搏；检查项目：心率，体重，湿性啰音，呼吸音，心电图，查体，心脏超声，T36CP，尿常规，碳酸氢根，子宫声像图，氧分压，肾输尿管膀胱超声，B型钠尿肽，促甲状腺激素，血管超声，浅静脉声像图，电解质氯，干化学法，颈动脉超声，凝血常规，ECLIA，冠状动脉CTA，子宫附件超声，血气全项，甲功五项，凝血酶原，病理性杂音，二氧化碳总含量，胸部CT，膀胱声像图，粒细胞，湿啰音，反跳痛，压痛；治疗方法：波立维，瑞舒伐他汀；身体部位：心前区，后背，三尖瓣，大小便，双肺，主动脉瓣，胸廓，冠状动脉，双肾，各瓣膜听诊区，腹部，双下肢动脉，深静脉，胆囊，肝，双下肢，左前降支，支中段心肌桥，腹；药物：瑞舒伐他汀，波立维；手术：胃息肉切除
# Predicted Label1: I20.800x007, True Label1: I20.800x007
# Text2: 疾病：高血压，胃息肉，房性早搏，室性早搏，传染病，结核，糖尿病，肝炎，慢性支气管炎，室上性早搏；症状：房性早搏，心律失常，室性早搏，心动过缓，多发结石，室上性早搏，感染，窦性心律；检查项目：凝血常规，血管超声，干化学法，甲功五项，颈动脉超声，尿常规，浅静脉声像图，凝血酶原，B型钠尿肽，电解质氯，ECLIA，子宫附件超声，胸部CT，超声，粒细胞，子宫声像，促甲状腺激素，血脂，血气全项，二氧化碳总含量，BNP，心率，血常规，心电图，血压，碳酸氢根，肾输尿管膀胱超声，冠状动脉CTA，肝功，氧分压，电解质，膀胱声像图，肾功，血糖；治疗方法：通心络胶囊，瑞舒伐他汀钙片，尼可地尔片；身体部位：肝，深静脉，胆囊，双下肢动脉，心肌桥，双侧输尿管，双肾，左前降支；药物：通心络胶囊，尼可地尔片，瑞舒伐他汀钙片；手术：胃息肉切除术，胃息肉切除
# Predicted Label2: ['I49.900']
# True Label2: ['I49.100x001']
# --------------------------------------------------
# Sample 3:
# Text1: 疾病：脑梗死，高血压，肝炎，糖尿病，心绞痛，结核，冠状动脉粥样硬化性心脏病，冠状动脉搭桥，不稳定型心绞痛，冠状动脉粥样硬化，慢性支气管炎，肺气肿；症状：怒张，畸形，粘痰，头痛，胸闷，呕吐，咳嗽，肿大，胸痛，隆起，凹陷，恶心，对称，头晕，肺大疱，钙化灶，气肿，结节，心绞痛，结石，渗血，渗液，心悸，狭窄，出血，水肿；检查项目：血压，干、湿性啰音，收缩压，体重，杂音，呼吸音，体格检查，心率，移动性浊音，半胱氨酸，ApoB，尿微量白蛋白，散射比浊法，尿β2微球蛋I，a1微球蛋白，肌钙蛋白，心电图，病理性杂音，H白，胸部X线，比浊法，冠状动脉CTA，叩痛，胸部CT，尿免疫球蛋白G，肠鸣音，尿转铁蛋白，单核细胞计数，红细胞压积，压痛，心脏超声，心脏彩超，尿糖，尿肌酐，反跳痛，甲功三项，葡萄糖测定，大便分析，凝血功能，肝素，糖化血红蛋白测定，湿性啰音，冠脉造影，C一反应蛋白测定，血小板功能动态监测，色谱法，查体，感染标志物系列，末梢血，凝血常规，CRP，电解质，酶法，心律；治疗方法：硝酸甘油，冠脉搭桥术；身体部位：胸廓，大小便，甲状腺，心前区，双肺，颈静脉，气管，双侧颈动脉，腹部，腹，肝，左房，主动脉瓣，脾，左室壁，室间隔，左肺上叶，左室，胆囊，各瓣膜听诊区，肾区，二、三尖瓣，右冠，后降支，冠脉，对角支，回旋支中段，管腔，股动脉，前降支中段，双侧肾上腺，左主干末端，左室后支，双下肢；药物：硝酸甘油，肝素；手术：冠脉搭桥术，冠状动脉搭桥
# Predicted Label1: I21.401, True Label1: I21.401
# Text2: 疾病：肝炎，高血压病，结核，脑梗死，肺大疱，阵发性心房颤动，糖尿病，胆囊结石，肺气肿，慢性支气管炎，冠状动脉粥样硬化；症状：阵发性心房颤动，心房颤动，狭窄，出血，返流，肺气肿，纤维灶双侧肾上腺显粗，增生可能冠状动脉搭桥术后CTA所见符合冠状动脉粥样硬化伴管腔不同程度狭窄，结节，胸闷，胸痛；检查项目：尿糖，收缩压，单核细胞计数，红细胞压积，肌钙蛋白，尿β2微球蛋I，H白，半胱氨酸，血压，尿免疫球蛋白G，葡萄糖测定，血小板功能动态监测，凝血常规，C一反应蛋白测定，甲功三项，糖化血红蛋白测定，尿肌酐，感染标志物，尿转铁蛋白，尿微量白蛋白，散射比浊法，比浊法，电解质，胸部CT，酶法，凝血功能，心脏彩超，a1微球蛋白，冠状动脉CTA，CRP，色谱法，肝素，肌酸激酶，血常规，血糖，肌钙蛋白I，末梢血，BNP，大便分析，心脏超声，肝肾功，血脂；治疗方法：冠脉搭桥术；身体部位：冠脉，左室后支，尿液，主动脉瓣，左主干末端，室间隔，室壁，左室，前降支中段，双肺，管腔，右冠，左室壁，双侧肾上腺，左房，二、三尖瓣；药物：青霉素，雷贝拉唑钠肠溶片，盐酸曲美他嗪片，速效救心丸，单硝酸异山梨酯缓释片，利伐沙班片，普罗布考片，琥珀酸美托洛尔缓释片，阿托伐他汀钙片，沙库巴曲沙坦钠片；手术：冠脉搭桥术，冠状动脉搭桥术
# Predicted Label2: ['I10.x00x032', 'I25.103']
# True Label2: ['I10.x00x032']
# --------------------------------------------------
# Sample 4:
# Text1: 疾病：冠心病不稳定型心绞痛，高血压，肺结节，冠状动脉粥样硬化性心脏病，不稳定型心绞痛，椎体终板炎，筋膜炎；症状：头晕，水肿，胸痛，咳嗽，头痛，心悸，咯血，腹痛，凹陷，出汗，胸闷，咳痰，发热，恶心，呕吐，喘，隐痛，隆起，腹泻，增厚，室上性早搏，狭窄，膨出，斑块形成（右侧多发）。双下肢动脉+双下肢深静脉+双下肢浅静脉超声：左侧小腿肌间静脉扩张，扩大，心律齐；检查项目：呼吸音，查体，Murphys征，干、湿性啰音，血压，R1，病理性杂音，反跳痛，肠鸣音，压痛，叩痛，心率，移动性浊音，胸部CT，BP，P，T3，丙氨酸转氨酶，天门冬氨酸转氨酶，心脏彩超，白蛋白，MR，潜血，ST-T，血，浅静脉超声，糖化血红蛋白，血检，前白蛋白，血沉，湿性啰音；治疗方法：硝苯地平缓释片；身体部位：肢体，肝，脾，双肺，肾区，左肺，心前区，腹，各瓣膜听诊区，双下肢，二便，右肺下叶，对角支，双下肢深静脉，左回旋支，左侧小腿肌间静脉，双侧颈动脉内中膜，腰5/1椎间盘，左主干，右冠状动脉，左前降支中段肌桥，腰椎，室间隔基底段，双下肢动脉；药物：硝苯地平缓释片；手术：冠脉造影术
# Predicted Label1: I20.800x007, True Label1: I20.000
# Text2: 疾病：高血压，结核，肝炎，高脂血症，肺结节，高血压病，慢阻肺，糖尿病，室上性早搏，椎体终板炎，筋膜炎；症状：痛经，狭窄，膨出，室上性早搏，扩张，出血，淤血，血尿，黑便，血便，瘀斑；检查项目：糖化血红蛋白，血沉，潜血，前白蛋白，血压，天门冬氨酸转氨酶，双侧颈动脉超声，血检，白蛋白，丙氨酸转氨酶，心脏彩超，ST-T，浅静脉超声，腰椎MR，肝功，肾功，电解质，血脂，血常规，血糖，心率，心电图，肌酸激酶；治疗方法：硝苯地平缓释片，阿利沙坦酯片，雷贝拉唑钠肠溶片，阿司匹林肠溶片，瑞舒伐他汀钙片；身体部位：左侧小腿肌间静脉，左回旋支，右冠状动脉，腰椎，左前降支中段肌桥，双下肢动脉，腰5/1椎间盘，左主干，胃部，双下肢深静脉，室间隔基底段，钝缘支，对角支，黏膜，皮肤；药物：硝苯地平缓释片，单硝酸异山梨酯缓释片，阿司匹林肠溶片，雷贝拉唑钠肠溶片，阿利沙坦酯片，瑞舒伐他汀钙片，阿司匹林，硝苯地平控释片，参松养心胶囊；手术：冠脉造影术
# Predicted Label2: ['I10.x00x028', 'I25.103', 'I70.806', 'Q24.501', 'R91.x00x003']
# True Label2: ['I70.806']
# --------------------------------------------------
# Sample 5:
# Text1: 疾病：结核，高血压病，冠心病，慢性支气管炎，肝炎，糖尿病；症状：腹泻，头晕，腹痛，咳痰，畸形，耳鸣，气，对称，头痛，水肿，隆起，咳嗽，恶心，呕吐，胸闷，凹陷；检查项目：体重，LVEF，肾动脉B超，查体，血压，病理性杂音，化验，BP，呼吸音，湿性啰音，钾，心脏彩超，心率，电解质，颈动脉B超，肾上腺CT，降压，反跳痛，压痛，血流声像图；治疗方法：降压药物；身体部位：左侧肾上腺，各瓣膜听诊区，胸廓，腹部，大小便，心前区，右侧颈动脉内中膜，双下肢，室间隔基底段，双肺，腹，双下肢足背动脉，双侧肾动脉；药物：降压药物；手术：
# Predicted Label1: I10.x00x032, True Label1: I10.x00x032
# Text2: 疾病：糖尿病，结核，高血压病，传染病，肝炎，慢性支气管炎，冠心病，脂肪肝；症状：脂肪肝；检查项目：血流声像图，肾上腺CT，颈动脉B超，化验，钾，LVEF，血糖，电解质，血压，心脏彩超，降压，肾动脉B超，心率；治疗方法：卡维地洛片，沙库巴曲沙坦钠片；身体部位：节段性室壁，双侧肾动脉，双肺，腹部，室间隔基底段，左侧肾上腺，胸部，右侧颈动脉内中膜；药物：沙库巴曲沙坦钠片，卡维地洛片；手术：
# Predicted Label2: ['K76.000']
# True Label2: ['E87.600']
# --------------------------------------------------
